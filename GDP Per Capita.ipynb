# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
from pandas_datareader import data, wb
import pandas_datareader as pdr
import matplotlib.pyplot as plt
import datetime as dt
import pandas as pd
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters() # Allow matplotlib have access to timestamp 
import matplotlib.ticker as mplticker

# %%
start = dt.datetime(1950, 1, 1)
end = dt.datetime.today()

country = ['Taiwan', 'US', 'India', 'China',
           'Pakistan', 'Syria', 'Korea', 'Argentina',
           'Japan', 'Italy', 'UK', 'Germany',
           'Cuba', 'Brazil', 'Indonesia']
GDP_PC_PPP = pdr.DataReader(['RGDPCHTWA625NUPN', #TW
                      'RGDPCHUSA625NUPN', #US
                      'RGDPCHINA625NUPN', #IN
                      'RGDPC2CNA625NUPN', #CN
                      'RGDPCHPKA625NUPN', #PA
                      'RGDPCHSYA625NUPN', #SY
                      'RGDPCHKRA625NUPN', #KR
                      'RGDPCHARA625NUPN', #AG
                      'RGDPCHJPA625NUPN', #JP
                      'RGDPCHITA625NUPN', #IT
                      'RGDPCHGBA625NUPN', #UK
                      'RGDPCHDEA625NUPN', #DE
                      'RGDPCHCUA625NUPN', #CU
                      'RGDPCHBRA625NUPN', #BR
                      'RGDPCHIDA625NUPN', #ID
                     ], 'fred', start, end)

# %%
GDP_PC_PPP.columns = country

# %%
GDP_PC_PPP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 61 entries, 1950-01-01 to 2010-01-01
# Data columns (total 15 columns):
# Taiwan       60 non-null float64
# US           61 non-null float64
# India        61 non-null float64
# China        59 non-null float64
# Pakistan     61 non-null float64
# Syria        51 non-null float64
# Korea        58 non-null float64
# Argentina    61 non-null float64
# Japan        61 non-null float64
# Italy        61 non-null float64
# UK           61 non-null float64
# Germany      41 non-null float64
# Cuba         41 non-null float64
# Brazil       61 non-null float64
# Indonesia    51 non-null float64
# dtypes: float64(15)
# memory usage: 7.6 KB

# %%
fig, ax = plt.subplots(figsize = (13, 8))
ax.plot(GDP_PC_PPP)
plt.show()
